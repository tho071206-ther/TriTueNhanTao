# %% [markdown]
# <a href="https://colab.research.google.com/github/tho071206-ther/TriTueNhanTao/blob/main/tuan3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bai thuc hanh tuan 3

# %%
print("hekkk")
# Out:
# hekkk
